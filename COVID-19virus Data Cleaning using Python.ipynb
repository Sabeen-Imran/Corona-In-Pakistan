# %%
import pandas as pd 
import numpy as np
import os

# %%
df=pd.read_excel(r'C:\Users\Haier\Desktop\COVID_FINAL_DATA.xlsx',0)
df.isnull().sum()
df=df.fillna(0)
df['Home Quarantine']=df['Home Quarantine'].apply(np.int64)
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace=True)
df
# Out:
#      Cumulative  Cumulative  Test positive  Cumulative  tests performed  \
# 0            48                          2                           80
# 1            61                          0                           95
# 2            84                         14                          171
# 3            20                          0                           28
# 4             3                          0                            0
# ..          ...                        ...                          ...
# 449        6224                        475                         5748
# 450       21257                        759                        21257
# 451       31568                       5021                        32577
# 452      114762                      13225                       140212
# 453       99117                      12610                        99117
#
#                     Date  Discharged  Expired  Home Quarantine  \
# ...

# %%
df.to_excel(r'C:\Users\Haier\Desktop\TimeSeries_KeyIndicators.xlsx',index=False)

# %%
df=pd.read_excel(r'C:\Users\Haier\Desktop\COVID_FINAL_DATA.xlsx',1)
df.isnull().sum()
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace=True)
df
# Out:
#           Date Province Old  Suspected Cases Last Date  \
# 0   2020-04-04          AJK                        322
# 1   2020-04-04  Balochistan                       2171
# 2   2020-04-04           GB                        961
# 3   2020-04-04          ICT                       2395
# 4   2020-04-04           KP                       1938
# ..         ...          ...                        ...
# 233 2020-05-13           GB                       6213
# 234 2020-05-13          ICT                      20201
# 235 2020-05-13           KP                      30597
# 236 2020-05-13       Punjab                     107603
# 237 2020-05-13        Sindh                      95053
#
#      Suspected Cases Last 24 Hrs  Suspected Cases Cumulative  \
# 0                             21                         343
# 1                            230                        2401
# 2                              2                         963
# ...

# %%
df.to_excel(r'C:\Users\Haier\Desktop\TimeSeries_KeyIndicators_Details.xlsx',index=False)

# %%
df=pd.read_excel(r'C:\Users\Haier\Desktop\COVID_FINAL_DATA.xlsx',2)
df.isnull().values.any()
df.to_excel(r'C:\Users\Haier\Desktop\TimeSeries_Action_Screen.xlsx',index=False)

# %%
df=pd.read_excel(r'C:\Users\Haier\Desktop\COVID_FINAL_DATA.xlsx',3)
df.isnull().values.any()
df.to_excel(r'C:\Users\Haier\Desktop\TimeSeries_Action_Call.xlsx',index=False)

# %%
df=pd.read_excel(r'C:\Users\Haier\Desktop\COVID_FINAL_DATA.xlsx',4)
df.isnull().sum()
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace=True)
df.to_excel(r'C:\Users\Haier\Desktop\TimeSeries_COVID_News.xlsx',index=False)

# %%
df=pd.read_excel(r'C:\Users\Haier\Desktop\COVID_FINAL_DATA.xlsx',5)
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace=True)
df.to_excel(r'C:\Users\Haier\Desktop\TimeSeries_NIH_Response.xlsx',index=False)

# %%
df=pd.read_excel(r'C:\Users\Haier\Desktop\COVID_FINAL_DATA.xlsx',6)
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace=True)
df.to_excel(r'C:\Users\Haier\Desktop\TimeSeries_NIH_Risk.xlsx',index=False)

# %%
df=pd.read_excel(r'C:\Users\Haier\Desktop\COVID_FINAL_DATA.xlsx',7)
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace=True)
df.to_excel(r'C:\Users\Haier\Desktop\TimeSeries_Province_Response.xlsx',index=False)

# %%
df=pd.read_excel(r'C:\Users\Haier\Desktop\COVID_FINAL_DATA.xlsx',8)
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace=True)
df.to_excel(r'C:\Users\Haier\Desktop\TimeSeries_Helpline_Calls.xlsx',index=False)

# %%
df=pd.read_excel(r'C:\Users\Haier\Desktop\COVID_FINAL_DATA.xlsx',9)
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace=True)
df.to_excel(r'C:\Users\Haier\Desktop\TimeSeries_Quarantine_Details.xlsx',index=False)

# %%
exit()
